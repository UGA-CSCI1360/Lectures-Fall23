# %% [markdown]
# # In-class Activity 14.2
#
# Print the values in the lists below following the format shown in the screenshot.
#
# ![Screenshot%20from%202023-11-30%2010-40-40.png](attachment:Screenshot%20from%202023-11-30%2010-40-40.png)

# %%
companies = ['Ford', 'Apple', 'Datamatics']
employees = [50000, 72130, 9400]
stocks = [10.288, 150.01, 2.69844]

# %%
# Out:
# Ford      		50,000		10.3
# ------------------------------------------------------------
# Apple     		72,130		150.0
# ------------------------------------------------------------
# Datamatics		9,400		2.7
# ------------------------------------------------------------
