# %% [markdown]
# # Activity 13.2
#
# The code in the cell below loads `uga.jpg` image. Blur the green channel in the image so it becomes similar to the image below.
#
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

from matplotlib.image import imread

img = imread('uga.jpg')

plt.imshow(img)
